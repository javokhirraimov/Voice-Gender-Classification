# %%
# !pip install datasets
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 14.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 12.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 18.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 15.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 22.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# ...

# %%
import glob
import os
import pandas as pd
import numpy as np
import shutil
import librosa
from tqdm import tqdm

# %%
from huggingface_hub import login
login(token="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")

# %%
from datasets import load_dataset

dataset = load_dataset('mozilla-foundation/common_voice_13_0', 'uz', split='train+validation')
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md:   0%|          | 0.00/14.7k [00:00<?, ?B/s]
# common_voice_13_0.py:   0%|          | 0.00/8.18k [00:00<?, ?B/s]
# languages.py:   0%|          | 0.00/3.65k [00:00<?, ?B/s]
# release_stats.py:   0%|          | 0.00/65.4k [00:00<?, ?B/s]
# ...

# %%
df = dataset.to_pandas()
df
# Out:
#                                                client_id  \
# 0      2160561702bac0e2048d2dc79810c2d8a6e6942a6dcac8...
# 1      2160561702bac0e2048d2dc79810c2d8a6e6942a6dcac8...
# 2      2160561702bac0e2048d2dc79810c2d8a6e6942a6dcac8...
# 3      2160561702bac0e2048d2dc79810c2d8a6e6942a6dcac8...
# 4      2160561702bac0e2048d2dc79810c2d8a6e6942a6dcac8...
# ...                                                  ...
# 60342  fdc71255d89ec313fff9d67325ed234728ec1b72eb783b...
# 60343  fdc71255d89ec313fff9d67325ed234728ec1b72eb783b...
# 60344  fdc71255d89ec313fff9d67325ed234728ec1b72eb783b...
# 60345  fdc71255d89ec313fff9d67325ed234728ec1b72eb783b...
# 60346  fdc71255d89ec313fff9d67325ed234728ec1b72eb783b...
#
#                                                     path  \
# 0      /root/.cache/huggingface/datasets/downloads/ex...
# 1      /root/.cache/huggingface/datasets/downloads/ex...
# 2      /root/.cache/huggingface/datasets/downloads/ex...
# ...

# %%
df = df[['path', 'gender']]
df
# Out:
#                                                     path gender
# 0      /root/.cache/huggingface/datasets/downloads/ex...   male
# 1      /root/.cache/huggingface/datasets/downloads/ex...   male
# 2      /root/.cache/huggingface/datasets/downloads/ex...   male
# 3      /root/.cache/huggingface/datasets/downloads/ex...   male
# 4      /root/.cache/huggingface/datasets/downloads/ex...   male
# ...                                                  ...    ...
# 60342  /root/.cache/huggingface/datasets/downloads/ex...   male
# 60343  /root/.cache/huggingface/datasets/downloads/ex...   male
# 60344  /root/.cache/huggingface/datasets/downloads/ex...   male
# 60345  /root/.cache/huggingface/datasets/downloads/ex...   male
# 60346  /root/.cache/huggingface/datasets/downloads/ex...   male
#
# [60347 rows x 2 columns]

# %%
df =  df[(df['gender'] == 'female') | (df['gender'] == 'male')]
df.shape
# Out:
# (33464, 2)

# %%
df.value_counts('gender')
# Out:
# gender
# male      21229
# female    12235
# Name: count, dtype: int64

# %%
df[df['gender'] == 'male'] = df[df['gender'] == 'male'].iloc[0:12235]
# Out:
# <ipython-input-9-b1e421fb85e7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df['gender'] == 'male'] = df[df['gender'] == 'male'].iloc[0:12235]
# <ipython-input-9-b1e421fb85e7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df['gender'] == 'male'] = df[df['gender'] == 'male'].iloc[0:12235]

# %%
df.value_counts('gender')
df
# Out:
#                                                     path gender
# 0      /root/.cache/huggingface/datasets/downloads/ex...   male
# 1      /root/.cache/huggingface/datasets/downloads/ex...   male
# 2      /root/.cache/huggingface/datasets/downloads/ex...   male
# 3      /root/.cache/huggingface/datasets/downloads/ex...   male
# 4      /root/.cache/huggingface/datasets/downloads/ex...   male
# ...                                                  ...    ...
# 60342                                                NaN    NaN
# 60343                                                NaN    NaN
# 60344                                                NaN    NaN
# 60345                                                NaN    NaN
# 60346                                                NaN    NaN
#
# [33464 rows x 2 columns]

# %%
# drop columns were values are equal to nan
df = df.dropna()
df
# Out:
#                                                     path  gender
# 0      /root/.cache/huggingface/datasets/downloads/ex...    male
# 1      /root/.cache/huggingface/datasets/downloads/ex...    male
# 2      /root/.cache/huggingface/datasets/downloads/ex...    male
# 3      /root/.cache/huggingface/datasets/downloads/ex...    male
# 4      /root/.cache/huggingface/datasets/downloads/ex...    male
# ...                                                  ...     ...
# 55746  /root/.cache/huggingface/datasets/downloads/ex...  female
# 55747  /root/.cache/huggingface/datasets/downloads/ex...  female
# 55748  /root/.cache/huggingface/datasets/downloads/ex...  female
# 55749  /root/.cache/huggingface/datasets/downloads/ex...  female
# 55750  /root/.cache/huggingface/datasets/downloads/ex...  female
#
# [24470 rows x 2 columns]

# %%
# shuffle the data
df = df.sample(frac=1).reset_index(drop=True)

# %%
df.iloc[5].path
# Out:
# '/root/.cache/huggingface/datasets/downloads/extracted/6ffb1928fe1a997fc14714069a9da68cceec6145c1d31f4c8bb0f60ebb8d98a6/uz_train_1/common_voice_uz_29476937.mp3'

# %%
dirname = 'data'
if not os.path.exists(dirname):
    os.mkdir(dirname)

# %%
df.to_csv('dataframe.csv', index=False)

# %%
folder_name = "/root/.cache/huggingface/datasets/downloads/extracted/b766c65406b2bd63d8b35ac17a3b7c3b76c438db77893954bc45a3252d243a45/uz_train_0/"
audio_files = glob.glob(f"{folder_name}*")
all_audio_files = list(df['path'])

# %%
len(all_audio_files)

# %%
features = []
for filename in os.listdir('/content/data'):
    if filename.endswith('.npy'):
        filepath = os.path.join('/content/data', filename)
        features.append(np.load(filepath))

np.save('features.npy', np.array(features))

# %%
import os
import numpy as np
import librosa
from tqdm import tqdm

def extract_features(file_name):
    """
    Extract mel-spectrogram features from an audio file.

    Parameters:
    - file_name (str): Path to the audio file.

    Returns:
    - np.ndarray: Extracted mel-spectrogram features or None if an error occurs.
    """
    try:
        data, sample_rate = librosa.load(file_name, sr=None)
        mel_spectrogram = librosa.feature.melspectrogram(y=data, sr=sample_rate)
        mel = np.mean(mel_spectrogram.T, axis=0)  # Compute the mean along the time axis
        return mel
    except Exception as e:
        print(f"Error processing file {file_name}: {e}")
        return None


# Define input folders (in the order to check)
input_folders = [
    "/root/.cache/huggingface/datasets/downloads/extracted/6ffb1928fe1a997fc14714069a9da68cceec6145c1d31f4c8bb0f60ebb8d98a6/uz_train_1/",
    "/root/.cache/huggingface/datasets/downloads/extracted/b766c65406b2bd63d8b35ac17a3b7c3b76c438db77893954bc45a3252d243a45/uz_train_0/"
]
target_base_folder = "/content/data"  # Directory to save extracted features

# Ensure the target base folder exists
os.makedirs(target_base_folder, exist_ok=True)

# Initialize counters
processed_files = 0
failed_files = 0

# Log lists
downloaded_files = []  # Successfully processed files
failed_files_list = []  # Files that failed to process

# Loop through all rows in the DataFrame
print(f"Total number of files to process: {df.shape[0]}")
for i, row in tqdm(df.iterrows(), total=df.shape[0], desc="Processing files"):
    audio_file = row['path']  # File path in the DataFrame
    print(f"\nProcessing file {audio_file}...")  # Log file being processed

    # Find the file in the defined input folders
    file_found = False
    for folder_name in input_folders:
        file_path = os.path.join(folder_name, audio_file)  # Combine folder path with the relative path
        if os.path.exists(file_path):
            file_found = True

            try:
                # Extract features
                features = extract_features(file_path)

                if features is not None:
                    # Determine the target save path
                    target_relative_path = os.path.relpath(file_path, folder_name)  # Get the relative path
                    target_path = os.path.join(target_base_folder, target_relative_path)  # Combine with target folder

                    # Ensure the target directory exists
                    os.makedirs(os.path.dirname(target_path), exist_ok=True)

                    # Save features as a .npy file
                    target_filename = os.path.splitext(target_path)[0]
                    np.save(target_filename, features)

                    processed_files += 1
                    downloaded_files.append(file_path)  # Log successfully processed file
                    print(f"Successfully processed {file_path}")  # Success message
                else:
                    print(f"Failed to extract features for {file_path}")
                    failed_files += 1
                    failed_files_list.append(file_path)  # Log failed file

            except Exception as e:
                print(f"Error processing {file_path}: {e}")
                failed_files += 1
                failed_files_list.append(file_path)  # Log failed file

            break  # Exit the loop once the file is found and processed

    if not file_found:
        print(f"File {audio_file} not found in any input folder.")
        failed_files += 1
        failed_files_list.append(audio_file)  # Log missing file

# Summary
print(f"\nProcessing complete: {processed_files} files processed, {failed_files} files failed.")
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# change the gender male to 1 female to 0
df['gender'] = df['gender'].replace({'male': 1, 'female': 0})
# Out:
# <ipython-input-41-bcc283736d65>:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['gender'] = df['gender'].replace({'male': 1, 'female': 0})

# %%
# take gender column and save in as np array in new file
np.save('label.npy', df['gender'].to_numpy().reshape(-1,1))

# %%
a = np.load('label.npy',  allow_pickle=True)
len(a)
# Out:
# 24470

# %%
features = []
for filename in os.listdir('/content/data'):
    if filename.endswith('.npy'):
        filepath = os.path.join('/content/data', filename)
        features.append(np.load(filepath))

np.save('features.npy', np.array(features))

# %% [markdown]
# Preprocessed File

# %%
# !unzip results.zip
# Out:
# Archive:  results.zip
#    creating: results/
#   inflating: results/features.npy
#   inflating: results/labels.npy
#   inflating: results/model.h5

# %%
def load_data(vector_length=128):


    if not os.path.isdir("results"):
        print("Results directory not found, please run the preprocessing script first.")
        return None, None

    # if features & labels already loaded individually and bundled, load them from there instead
    if os.path.isfile("results/features.npy") and os.path.isfile("results/labels.npy"):
        X = np.load("results/features.npy")
        y = np.load("results/labels.npy")
        return X, y

# %%
X, y = load_data()

# %%
len(X)
# Out:
# 66938

# %%
from sklearn.model_selection import train_test_split
def split_data(X, y, test_size=0.1, valid_size=0.1):
    # split training set and testing set
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=7)
    # split training set and validation set
    X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size=valid_size, random_state=7)
    # return a dictionary of values
    return {
        "X_train": X_train,
        "X_valid": X_valid,
        "X_test": X_test,
        "y_train": y_train,
        "y_valid": y_valid,
        "y_test": y_test
    }

# %%
data = split_data(X, y, test_size=0.1, valid_size=0.1)

# %%
data
# Out:
# {'X_train': array([[3.18345410e-04, 4.64542158e-04, 1.33341625e-02, ...,
#          1.29369393e-04, 1.13253909e-05, 1.21225796e-07],
#         [6.04928564e-03, 4.18074615e-02, 2.46937320e-01, ...,
#          5.61061643e-06, 2.34860772e-06, 2.02282308e-07],
#         [1.70664207e-04, 2.59609544e-04, 1.13360574e-02, ...,
#          4.08317137e-05, 1.23200834e-05, 6.61388299e-07],
#         ...,
#         [6.53586611e-02, 6.59793913e-02, 9.34694931e-02, ...,
#          1.11884573e-08, 6.17724227e-09, 1.94925120e-09],
#         [3.11283465e-03, 2.94779823e-03, 3.44930729e-03, ...,
#          5.08225244e-03, 1.52768986e-03, 1.18419994e-04],
#         [1.99342277e-04, 3.76800454e-04, 2.73060257e-04, ...,
#          1.32286596e-05, 2.71400404e-06, 1.57129577e-07]]),
#  'X_valid': array([[1.48561429e-02, 9.71583463e-03, 3.98743749e-02, ...,
#          1.17317761e-07, 7.82851686e-08, 6.27862473e-09],
#         [5.70136216e-03, 3.62047413e-03, 7.89002329e-03, ...,
# ...

# %%
! pip install tensorflow

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout

# %%
model = Sequential()
model.add(Dense(256, input_shape=(128,)))
model.add(Dropout(0.3))
model.add(Dense(256, activation="relu"))
model.add(Dropout(0.3))
model.add(Dense(128, activation="relu"))
model.add(Dropout(0.3))
model.add(Dense(128, activation="relu"))
model.add(Dropout(0.3))
model.add(Dense(64, activation="relu"))
model.add(Dropout(0.3))
# one output neuron with sigmoid activation function, 0 means female, 1 means male
model.add(Dense(1, activation="sigmoid"))
# using binary crossentropy as it's male/female classification (binary)
model.compile(loss="binary_crossentropy", metrics=["accuracy"], optimizer="adam")
# print summary of the model
model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 256)                 │          33,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# ...

# %%
batch_size = 64
epochs = 100

# %%
model.fit(data["X_train"], data["y_train"], epochs=epochs, batch_size=batch_size, validation_data=(data["X_valid"], data["y_valid"]))
# Out:
# Epoch 1/100
# 848/848 ━━━━━━━━━━━━━━━━━━━━ 19s 13ms/step - accuracy: 0.7048 - loss: 0.6777 - val_accuracy: 0.8523 - val_loss: 0.3696
# Epoch 2/100
# 848/848 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - accuracy: 0.8264 - loss: 0.4303 - val_accuracy: 0.8636 - val_loss: 0.3713
# Epoch 3/100
# 848/848 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8471 - loss: 0.3919 - val_accuracy: 0.8762 - val_loss: 0.3235
# Epoch 4/100
# 848/848 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8618 - loss: 0.3584 - val_accuracy: 0.8747 - val_loss: 0.3219
# Epoch 5/100
# 848/848 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8626 - loss: 0.3525 - val_accuracy: 0.8860 - val_loss: 0.2938
# Epoch 6/100
# 848/848 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8715 - loss: 0.3385 - val_accuracy: 0.8900 - val_loss: 0.2853
# Epoch 7/100
# 848/848 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8766 - loss: 0.3219 - val_accuracy: 0.8921 - val_loss: 0.2731
# Epoch 8/100
# ...

# %%
model.save("results/model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# Gradio

# %%
# !pip install gradio
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 MB 14.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 321.8/321.8 kB 27.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.8/94.8 kB 9.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 98.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 kB 6.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 5.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: markupsafe
#     Found existing installation: MarkupSafe 3.0.2
#     Uninstalling MarkupSafe-3.0.2:
#       Successfully uninstalled MarkupSafe-3.0.2
# ...

# %%
import json
import time
def classify_gender(file1,file2):

    file = file1 if file1 else file2

    #get audio length
    audio_length = librosa.get_duration(filename=file)

    start = time.time()
    features = extract_features(file, mel=True).reshape(1, -1)
    male_prob = model.predict(features)[0][0]
    female_prob = 1 - male_prob
    gender = "male" if male_prob > female_prob else "female"
    text = f"Result: Probabilities:     Male: {male_prob*100:.2f}%    Female: {female_prob*100:.2f}%"
    end = time.time()
    final_time = end - start

    result = {
        "gender": gender,
        "male_probability": f"{male_prob*100:.2f}%",
        "female_probability": f"{female_prob*100:.2f}%",
        "Time taken": f"{final_time:.2f} seconds",
        "Audio length": f"{audio_length:.2f} seconds",
    }


    return json.dumps(result)

import gradio as gr
# Replace 'source' with 'sources' and provide a list of sources
demo = gr.Interface(fn=classify_gender, inputs=[gr.Audio(sources=["upload"],type="filepath"),gr.Audio(sources=["microphone"],type="filepath")], outputs="json")
demo.launch(share=True)
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://fd479dee82c967739a.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://fd479dee82c967739a.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
import gradio as gr
# Replace 'source' with 'sources' and provide a list of sources
demo = gr.Interface(fn=classify_gender, inputs=[gr.Audio(sources=["upload"],type="filepath"),gr.Audio(sources=["microphone"],type="filepath")], outputs="json")
demo.launch(share=True)
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://f25f332d2dcfcc4021.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://f25f332d2dcfcc4021.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
